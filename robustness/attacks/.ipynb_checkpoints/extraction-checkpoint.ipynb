# %% [markdown]
# # Model Extraction
#
# ---
#
# ## 1. MIFace (Model inversion)
#
# **API Reference:**
# - https://adversarial-robustness-toolbox.readthedocs.io/en/latest/modules/attacks/inference/model_inversion.html
#
# **Related paper:**
# - https://dl.acm.org/doi/10.1145/2810103.2813677
#
# ---

# %%
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
tf.compat.v1.disable_eager_execution() # To use the ART

import tensorflow.keras.backend as k
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

import numpy as np
from numpy.random import seed
seed(123)

from art.estimators.classification import KerasClassifier
from art.attacks.inference.model_inversion.mi_face import MIFace
from art.utils import load_dataset

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Read MNIST dataset
(x_train, y_train), (x_test, y_test), min_, max_ = load_dataset(str('mnist'))

# %% [markdown]
# ### Train model using MNIST dataset

# %%
# create standard CNN in Keras and wrap with ART KerasClassifier:
def cnn_mnist(input_shape, min_val, max_val):
  
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    classifier = KerasClassifier(clip_values=(min_val, max_val), 
                                model=model, use_logits=False)
    return classifier

# %%
num_epochs = 10

# Construct and train a convolutional neural network
classifier = cnn_mnist(x_train.shape[1:], min_, max_)
classifier.fit(x_train, y_train, nb_epochs=num_epochs, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 2021-12-20 18:09:46.225569: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.226022: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.226708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.227048: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.227694: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.227986: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.228628: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.229001: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.229680: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.230079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20797 MB memory:  -> device: 0, name: TITAN RTX, pci bus id: 0000:01:00.0, compute capability: 7.5
# 2021-12-20 18:09:46.230164: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-12-20 18:09:46.230753: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 18745 MB memory:  -> device: 1, name: TITAN RTX, pci bus id: 0000:04:00.0, compute capability: 7.5
# 2021-12-20 18:09:46.705418: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8101
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.2257 - accuracy: 0.9327
# Epoch 2/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0652 - accuracy: 0.9798
# Epoch 3/10
# 60000/60000 [==============================] - 3s 42us/sample - loss: 0.0471 - accuracy: 0.9857
# Epoch 4/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0372 - accuracy: 0.9883
# Epoch 5/10
# 60000/60000 [==============================] - 2s 40us/sample - loss: 0.0311 - accuracy: 0.9903
# Epoch 6/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0268 - accuracy: 0.9910
# Epoch 7/10
# 60000/60000 [==============================] - 2s 39us/sample - loss: 0.0217 - accuracy: 0.9928
# Epoch 8/10
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.0189 - accuracy: 0.9941
# Epoch 9/10
# 60000/60000 [==============================] - 3s 46us/sample - loss: 0.0176 - accuracy: 0.9939
# Epoch 10/10
# 60000/60000 [==============================] - 2s 41us/sample - loss: 0.0154 - accuracy: 0.9951

# %% [markdown]
# ### Initialize attack

# %%
# Create the attack.
# Note: by setting the threshold to 1., the attack will effectively exhaust the maximum number of iterations.

attack = MIFace(classifier, max_iter=10000, threshold=1.)

# %%
# Our attack target in the following will be to infer information about the training samples 
# for each of the 10 MNIST CLASSES:

y = np.arange(10)

# %%
# We will experiment with a number of different initializations:

x_init_white = np.zeros((10, 28, 28, 1))
x_init_grey = np.zeros((10, 28, 28, 1)) + 0.5
x_init_black = np.ones((10, 28, 28, 1))
x_init_random = np.random.uniform(0, 1, (10, 28, 28, 1))
x_init_average = np.zeros((10, 28, 28, 1)) + np.mean(x_test, axis=0)

# %% [markdown]
# ### Initialization with white image

# %%
# We observe that the classifier's gradients are vanishing on white images, therefore the attack won't work:

print("Maximum class gradient: %f" % (np.max(np.abs(classifier.class_gradient(x_init_white, y)))))
# Out:
# Maximum class gradient: 0.000000

# %% [markdown]
# ### Initialization with grey image

# %%
# First, we ensure that the classifier's gradients are non-vanishing for each target class:

class_gradient = classifier.class_gradient(x_init_grey, y)
class_gradient = np.reshape(class_gradient, (10, 28*28))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# Minimum over all maximum class gradient: 0.008055

# %%
# %%time

# Now we run the attack:
x_infer_from_grey = attack.infer(x_init_grey, y)
# Out:
# Model inversion:   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 22min 10s, sys: 2min 17s, total: 24min 28s
# Wall time: 13min 57s

# %%
# Plot the inferred images:

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow( (np.reshape(x_infer_from_grey[0+i,], (28, 28))), cmap=plt.cm.gray_r)

# %% [markdown]
# As we can see, the attack reveals certain structural properties of the training instances for each
# of the ten classes.

# %% [markdown]
# ### Initialization with black image

# %%
# First, we ensure that the classifier's gradients are non-vanishing for each target class:

class_gradient = classifier.class_gradient(x_init_black, y)
class_gradient = np.reshape(class_gradient, (10, 28*28))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# Minimum over all maximum class gradient: 0.000209

# %%
# %%time

# Now we run the attack:
x_infer_from_black = attack.infer(x_init_black, y)
# Out:
# Model inversion:   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 22min 8s, sys: 2min 17s, total: 24min 26s
# Wall time: 13min 57s

# %%
# Plot the inferred images:

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow( (np.reshape(x_infer_from_black[0+i,], (28, 28))), cmap=plt.cm.gray_r)

# %% [markdown]
# ### Initialization with random image

# %%
# First, we ensure that the classifier's gradients are non-vanishing for each target class:

class_gradient = classifier.class_gradient(x_init_random, y)
class_gradient = np.reshape(class_gradient, (10, 28*28))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# Minimum over all maximum class gradient: 0.001326

# %%
# %%time

# Now we run the attack:
x_infer_from_random = attack.infer(x_init_random, y)
# Out:
# Model inversion:   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 22min 10s, sys: 2min 17s, total: 24min 27s
# Wall time: 13min 56s

# %%
# Plot the inferred images:

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow( (np.reshape(x_infer_from_random[0+i,], (28, 28))), cmap=plt.cm.gray_r)

# %% [markdown]
# ### Initialization with average image

# %%
# First, we ensure that the classifier's gradients are non-vanishing for each target class:

class_gradient = classifier.class_gradient(x_init_average, y)
class_gradient = np.reshape(class_gradient, (10, 28*28))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# Minimum over all maximum class gradient: 0.020292

# %%
# %%time

# Now we run the attack:
x_infer_from_average = attack.infer(x_init_average, y)
# Out:
# Model inversion:   0%|          | 0/10 [00:00<?, ?it/s]
# CPU times: user 21min 47s, sys: 2min 14s, total: 24min 2s
# Wall time: 13min 42s

# %%
# Plot the inferred images:

plt.figure(figsize=(15,15))
for i in range(10):
    plt.subplot(5, 5, i + 1)
    plt.imshow( (np.reshape(x_infer_from_average[0+i,], (28, 28))), cmap=plt.cm.gray_r)

# %% [markdown]
# ---
#
# ## 2. Model stealing (Copycat CNN, Knockoff Nets)
#
# **API Reference:**
# - Copycat CNN: https://adversarial-robustness-toolbox.readthedocs.io/en/latest/modules/attacks/extraction.html#copycat-cnn
# - Knockoff Nets: https://adversarial-robustness-toolbox.readthedocs.io/en/latest/modules/attacks/extraction.html#knockoff-nets
#
# **Related paper:**
# - Copycat CNN: https://arxiv.org/abs/1806.05476
# - Knockoff Nets: https://arxiv.org/abs/1812.02766
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Flatten, InputLayer, Reshape

from art.estimators.classification import KerasClassifier

if tf.executing_eagerly():
    tf.python.framework.ops.disable_eager_execution()

# %% [markdown]
# ### Load dataset (MNIST)

# %%
import art
from art.utils import load_mnist

# Load the dataset, and split the test data into test and steal datasets.
(x_train, y_train), (x_test0, y_test0), _, _ = load_mnist()
len_steal = 5000
indices = np.random.permutation(len(x_test0))
x_steal = x_test0[indices[:len_steal]]
y_steal = y_test0[indices[:len_steal]]
x_test = x_test0[indices[len_steal:]]
y_test = y_test0[indices[len_steal:]]

# %% [markdown]
# ### Train model

# %%
im_shape = x_train[0].shape
def get_model(num_classes=10, c1=32, c2=64, d1=128):
    model = Sequential()
    model.add(Conv2D(c1, kernel_size=(3, 3), activation='relu', input_shape=im_shape))
    model.add(Conv2D(c2, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(d1, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss=tf.keras.losses.categorical_crossentropy, optimizer="sgd",
                          metrics=['accuracy'])
    return model

# %%
num_epochs = 5
model = get_model(num_classes=10, c1=32, c2=64, d1=128)
print("Original model training:")
model.fit(x_train, y_train, batch_size=100, epochs=num_epochs)
print("Original model evaluation:")
print(model.evaluate(x_test, y_test))

classifier_original = KerasClassifier(model, clip_values=(0, 1), use_logits=False)
# Out:
# Original model training:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.8001 - accuracy: 0.7907
# Epoch 2/5
# 60000/60000 [==============================] - 2s 38us/sample - loss: 0.2500 - accuracy: 0.9258
# Epoch 3/5
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1863 - accuracy: 0.9447
# Epoch 4/5
# 60000/60000 [==============================] - 4s 63us/sample - loss: 0.1503 - accuracy: 0.9550
# Epoch 5/5
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.1287 - accuracy: 0.9616
# Original model evaluation:
# [0.13104453050494194, 0.961]

# %% [markdown]
# ### Stealing from the unprotected classifier

# %%
from art.attacks import ExtractionAttack
from art.attacks.extraction import CopycatCNN, KnockoffNets

attack_catalogue = {"Probabilistic CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax CopycatCNN": CopycatCNN(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                    "Probabilistic KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=True),
                    "Argmax KnockoffNets": KnockoffNets(classifier=classifier_original,
                                              batch_size_fit=64,
                                              batch_size_query=64,
                                              nb_epochs=num_epochs,
                                              nb_stolen=len_steal,
                                              use_probability=False),
                   }

results = []
for len_steal in [250, 500, 1000, 2000, 4000, 5000]:
    indices = np.random.permutation(len(x_test0))
    x_steal = x_test0[indices[:len_steal]]
    y_steal = y_test0[indices[:len_steal]]
    x_test = x_test0[indices[len_steal:]]
    y_test = y_test0[indices[len_steal:]]

    for name, attack in attack_catalogue.items():
        model_stolen = get_model(num_classes=10, c1=32, c2=64, d1=128)
        classifier_stolen = KerasClassifier(model_stolen, clip_values=(0, 1), use_logits=False)
        classifier_stolen = attack.extract(x_steal, y_steal, thieved_classifier=classifier_stolen)
        acc = classifier_stolen._model.evaluate(x_test, y_test)[1]
        print(name, ":", acc)
        results.append((name, len_steal, acc))
# Out:
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 370us/sample - loss: 2.2941 - accuracy: 0.1080
# Epoch 2/5
# 250/250 [==============================] - 0s 43us/sample - loss: 2.2806 - accuracy: 0.1560
# Epoch 3/5
# 250/250 [==============================] - 0s 40us/sample - loss: 2.2668 - accuracy: 0.2360
# Epoch 4/5
# 250/250 [==============================] - 0s 39us/sample - loss: 2.2525 - accuracy: 0.2640
# Epoch 5/5
# 250/250 [==============================] - 0s 39us/sample - loss: 2.2367 - accuracy: 0.3280
# Probabilistic CopycatCNN : 0.34984615
# Train on 250 samples
# Epoch 1/5
# 250/250 [==============================] - 0s 204us/sample - loss: 2.3025 - accuracy: 0.1440
# Epoch 2/5
# 250/250 [==============================] - 0s 42us/sample - loss: 2.2864 - accuracy: 0.1840
# Epoch 3/5
# 250/250 [==============================] - 0s 42us/sample - loss: 2.2708 - accuracy: 0.2200
# Epoch 4/5
# 250/250 [==============================] - 0s 42us/sample - loss: 2.2541 - accuracy: 0.2400
# Epoch 5/5
# 250/250 [==============================] - 0s 41us/sample - loss: 2.2383 - accuracy: 0.2480
# Argmax CopycatCNN : 0.24748717
# Probabilistic KnockoffNets : 0.16635898
# Argmax KnockoffNets : 0.25323078
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 0s 174us/sample - loss: 2.2912 - accuracy: 0.1360
# Epoch 2/5
# 500/500 [==============================] - 0s 39us/sample - loss: 2.2718 - accuracy: 0.1820
# Epoch 3/5
# 500/500 [==============================] - 0s 37us/sample - loss: 2.2503 - accuracy: 0.2160
# Epoch 4/5
# 500/500 [==============================] - 0s 39us/sample - loss: 2.2258 - accuracy: 0.2980
# Epoch 5/5
# 500/500 [==============================] - 0s 38us/sample - loss: 2.1954 - accuracy: 0.3440
# Probabilistic CopycatCNN : 0.29189473
# Train on 500 samples
# Epoch 1/5
# 500/500 [==============================] - 0s 133us/sample - loss: 2.2853 - accuracy: 0.1260
# Epoch 2/5
# 500/500 [==============================] - 0s 41us/sample - loss: 2.2507 - accuracy: 0.2180
# Epoch 3/5
# 500/500 [==============================] - 0s 38us/sample - loss: 2.2150 - accuracy: 0.2720
# Epoch 4/5
# 500/500 [==============================] - 0s 37us/sample - loss: 2.1732 - accuracy: 0.3440
# Epoch 5/5
# 500/500 [==============================] - 0s 41us/sample - loss: 2.1213 - accuracy: 0.4140
# Argmax CopycatCNN : 0.38610527
# Probabilistic KnockoffNets : 0.42357895
# Argmax KnockoffNets : 0.30736843
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 109us/sample - loss: 2.2825 - accuracy: 0.1460
# Epoch 2/5
# 1000/1000 [==============================] - 0s 40us/sample - loss: 2.2318 - accuracy: 0.3180
# Epoch 3/5
# 1000/1000 [==============================] - 0s 40us/sample - loss: 2.1657 - accuracy: 0.3740
# Epoch 4/5
# 1000/1000 [==============================] - 0s 39us/sample - loss: 2.0578 - accuracy: 0.4550
# Epoch 5/5
# 1000/1000 [==============================] - 0s 95us/sample - loss: 1.8629 - accuracy: 0.5620
# Probabilistic CopycatCNN : 0.6116667
# Train on 1000 samples
# Epoch 1/5
# 1000/1000 [==============================] - 0s 90us/sample - loss: 2.2831 - accuracy: 0.1680
# Epoch 2/5
# 1000/1000 [==============================] - 0s 39us/sample - loss: 2.2425 - accuracy: 0.2510
# Epoch 3/5
# 1000/1000 [==============================] - 0s 57us/sample - loss: 2.1887 - accuracy: 0.4140
# Epoch 4/5
# 1000/1000 [==============================] - 0s 65us/sample - loss: 2.0979 - accuracy: 0.5260
# Epoch 5/5
# 1000/1000 [==============================] - 0s 66us/sample - loss: 1.9229 - accuracy: 0.6220
# Argmax CopycatCNN : 0.65966666
# Probabilistic KnockoffNets : 0.67777777
# Argmax KnockoffNets : 0.7218889
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 0s 73us/sample - loss: 2.2634 - accuracy: 0.2170
# Epoch 2/5
# 2000/2000 [==============================] - 0s 42us/sample - loss: 2.1109 - accuracy: 0.3875
# Epoch 3/5
# 2000/2000 [==============================] - 0s 54us/sample - loss: 1.6279 - accuracy: 0.6555
# Epoch 4/5
# 2000/2000 [==============================] - 0s 79us/sample - loss: 0.8689 - accuracy: 0.8230
# Epoch 5/5
# 2000/2000 [==============================] - 0s 79us/sample - loss: 0.5507 - accuracy: 0.8680
# Probabilistic CopycatCNN : 0.8495
# Train on 2000 samples
# Epoch 1/5
# 2000/2000 [==============================] - 0s 69us/sample - loss: 2.2319 - accuracy: 0.2150
# Epoch 2/5
# 2000/2000 [==============================] - 0s 99us/sample - loss: 1.9652 - accuracy: 0.5760
# Epoch 3/5
# 2000/2000 [==============================] - 0s 94us/sample - loss: 1.2330 - accuracy: 0.7650
# Epoch 4/5
# 2000/2000 [==============================] - 0s 48us/sample - loss: 0.6293 - accuracy: 0.8400
# Epoch 5/5
# 2000/2000 [==============================] - 0s 48us/sample - loss: 0.4573 - accuracy: 0.8650
# Argmax CopycatCNN : 0.810125
# Probabilistic KnockoffNets : 0.835625
# Argmax KnockoffNets : 0.754875
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 0s 57us/sample - loss: 2.1517 - accuracy: 0.4288
# Epoch 2/5
# 4000/4000 [==============================] - 0s 37us/sample - loss: 1.1102 - accuracy: 0.7513
# Epoch 3/5
# 4000/4000 [==============================] - 0s 34us/sample - loss: 0.4970 - accuracy: 0.8650
# Epoch 4/5
# 4000/4000 [==============================] - 0s 44us/sample - loss: 0.3837 - accuracy: 0.9018
# Epoch 5/5
# 4000/4000 [==============================] - 0s 64us/sample - loss: 0.3332 - accuracy: 0.9197
# Probabilistic CopycatCNN : 0.8668333
# Train on 4000 samples
# Epoch 1/5
# 4000/4000 [==============================] - 0s 65us/sample - loss: 2.1557 - accuracy: 0.4790
# Epoch 2/5
# 4000/4000 [==============================] - 0s 66us/sample - loss: 1.1513 - accuracy: 0.7570
# Epoch 3/5
# 4000/4000 [==============================] - 0s 66us/sample - loss: 0.4409 - accuracy: 0.8723
# Epoch 4/5
# 4000/4000 [==============================] - 0s 52us/sample - loss: 0.3210 - accuracy: 0.8942
# Epoch 5/5
# 4000/4000 [==============================] - 1s 129us/sample - loss: 0.2770 - accuracy: 0.9087
# Argmax CopycatCNN : 0.873
# Probabilistic KnockoffNets : 0.8181667
# Argmax KnockoffNets : 0.8958333
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 0s 58us/sample - loss: 2.1042 - accuracy: 0.4492
# Epoch 2/5
# 5000/5000 [==============================] - 0s 39us/sample - loss: 0.8572 - accuracy: 0.8092
# Epoch 3/5
# 5000/5000 [==============================] - 0s 40us/sample - loss: 0.4198 - accuracy: 0.8926
# Epoch 4/5
# 5000/5000 [==============================] - 0s 50us/sample - loss: 0.3573 - accuracy: 0.9086
# Epoch 5/5
# 5000/5000 [==============================] - 0s 82us/sample - loss: 0.3197 - accuracy: 0.9196
# Probabilistic CopycatCNN : 0.888
# Train on 5000 samples
# Epoch 1/5
# 5000/5000 [==============================] - 0s 92us/sample - loss: 2.1136 - accuracy: 0.4462
# Epoch 2/5
# 5000/5000 [==============================] - 0s 70us/sample - loss: 0.8466 - accuracy: 0.8124
# Epoch 3/5
# 5000/5000 [==============================] - 0s 58us/sample - loss: 0.3870 - accuracy: 0.8796
# Epoch 4/5
# 5000/5000 [==============================] - 0s 67us/sample - loss: 0.3025 - accuracy: 0.9036
# Epoch 5/5
# 5000/5000 [==============================] - 0s 60us/sample - loss: 0.2728 - accuracy: 0.9118
# Argmax CopycatCNN : 0.8998
# Probabilistic KnockoffNets : 0.892
# Argmax KnockoffNets : 0.8848

# %%
import pandas as pd
df = pd.DataFrame(results, columns=('Method Name', 'Stealing Dataset Size', 'Accuracy'))
fig, ax = plt.subplots(figsize=(8,6))
ax.set_xlabel("Stealing Dataset Size")
ax.set_ylabel("Stolen Model Accuracy")
for name, group in df.groupby("Method Name"):
    group.plot(1, 2, ax=ax, label=name)
plt.show()
